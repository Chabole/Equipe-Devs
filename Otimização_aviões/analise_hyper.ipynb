# %%
import numpy as np
import ZebraLib as zb
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import itertools

# %%
df = pd.read_excel('D:/outputs_aviões.xlsx', index_col=0)
df = df.rename({'Slo_EDO': 'Slo'}, axis = 1)

# %%
df.columns
# Out:
# Index(['ano', 'nome', 'b', 'S', 'Af', 'AR', 'CLn', 'CLmax', 'Swet', 'c', 'ao',
#        'a_max', 'St', 'CLt', 'zt', 'Tc_0', 'Tc_1', 'Tc_2', 'mi', 'mv', 'Nmax',
#        'z', 'I', 'xw', 'xm', 'xn', 'Slo'],
#       dtype='object')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='Slo', y='S', alpha=.4, 
            s=filtro_2['AR'], label='AR', figsize=(10,7), 
            c='Af', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='Slo', y='S', alpha=.4, 
            s=filtro_2['AR'], label='AR', figsize=(10,7), 
            c='CLmax', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='Slo', y='S', alpha=.4, 
            s=filtro_2['AR'], label='AR', figsize=(10,7), 
            c='c', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='AR', y='S', alpha=.4, 
            s=filtro_2['Af']*10, label='Af', figsize=(10,7), 
            c='Slo', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='AR', y='S', alpha=.4, 
            s=filtro_2['Af']*10, label='Af', figsize=(10,7), 
            c='Af', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='c', y='S', alpha=.4, 
            s=filtro_2['Af'], label='Af', figsize=(10,7), 
            c='Slo', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='c', y='AR', alpha=.4, 
            s=filtro_2['Af'], label='Af', figsize=(10,7), 
            c='Slo', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='CLmax', y='AR', alpha=.4, 
            s=filtro_2['Af'], label='Af', figsize=(10,7), 
            c='Slo', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot.hexbin(x="AR", y="S", gridsize=90);
plt.grid(linestyle='dotted')

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 30)]
filtro_2.plot(kind='scatter', x='b', y='c', alpha=.4, 
            label='Af', figsize=(10,7), 
            c='Slo', cmap=plt.get_cmap('jet'), colorbar=True)

plt.grid(linestyle='dotted')
