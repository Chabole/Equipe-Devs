# %%
import numpy as np
import ZebraLib as zb
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import itertools

# %%
df = pd.read_excel('D:/resultados_aviões_BRABO.xlsx', index_col=0)

# %%
filtro_df = df[(df['S'] < 1.5) & (df['b'] < 2.5) & (df['AR'] < 4)]
filtro_df[filtro_df.index==filtro_df['Slo'].idxmin()]
# Out:
#          ano     nome         b         S        Af        AR   CLn     CLmax  \
# 102717  2021  Zb 2021  1.867347  1.497362  0.169388  3.986996  1.08  1.564849
#
#         Swet         c  ...    Tc_2     mi   mv  Nmax     z  I  xw    xm  \
# 102717    10  0.468359  ...  35.225  0.038  2.8   2.1  0.22  1   0  0.25
#
#           xn        Slo
# 102717  0.15  12.443476
#
# [1 rows x 27 columns]

# %%
filtro_df[['b', 'S', 'Af', 'AR', 'c', 'CLmax', 'Slo']].hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'b'}>,
#         <AxesSubplot:title={'center':'S'}>,
#         <AxesSubplot:title={'center':'Af'}>],
#        [<AxesSubplot:title={'center':'AR'}>,
#         <AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'CLmax'}>],
#        [<AxesSubplot:title={'center':'Slo'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
filtro_2 = df[(df['Slo'] > 3) & (df['Slo'] <= 50)]
filtro_2.plot(kind='scatter', x='AR', y='S', alpha=1, 
            s=filtro_2['Af'], label='Af', figsize=(10,7), 
            c='Slo', cmap=plt.get_cmap('jet'), colorbar=True)
            
print('oi')
# Out:
# oi
